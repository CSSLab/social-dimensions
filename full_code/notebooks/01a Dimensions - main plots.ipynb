# %%
import sys
import os
sys.path.append("..")

# %config InlineBackend.figure_format = 'retina'
# %config InlineBackend.print_figure_kwargs={'facecolor' : "w"}

# %load_ext autoreload
# %autoreload 2
from commembed.jupyter import *
from commembed.plots.social_dimensions import *
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
render_fig1_regular("partisan")
plt.show()
# Out:
# /ada/projects/commembed/notebooks_final/../commembed/plots/social_dimensions.py:526: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)

# %%
render_fig1_grid(["age","gender","partisan","affluence"])
pass
# Out:
# /ada/projects/commembed/notebooks_final/../commembed/plots/social_dimensions.py:526: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)

# %%
save_paper_figure(render_fig1_regular("partisan"), "fig_1_schematic")
save_paper_figure(render_fig1_grid(), "fig_A_1_schematic_grid", filetype='tiff')
# Out:
# Aspect ratio: 0.6688
# Saved fig_1_schematic
# /ada/projects/commembed/notebooks_final/../commembed/plots/social_dimensions.py:526: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# Aspect ratio: 1.0162
# Saved fig_A_1_schematic_grid

# %%
many_densities_plot(['age', 'gender', 'partisan'], percentilize=True, single_column=True)
plt.show()
# Out:
# /ada/projects/commembed/notebooks_final/../commembed/plots/social_dimensions.py:271: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   to_scatter = to_scatter[np.abs(x - mean) >= render_thresh]
# /ada/projects/commembed/notebooks_final/../commembed/plots/social_dimensions.py:271: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   to_scatter = to_scatter[np.abs(x - mean) >= render_thresh]
# /ada/projects/commembed/notebooks_final/../commembed/plots/social_dimensions.py:271: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   to_scatter = to_scatter[np.abs(x - mean) >= render_thresh]

# %%
many_densities_plot(['age', 'gender', 'partisan'], clustering_name="reddit_all_numbered", percentilize=False)
plt.show()
# Out:
# /ada/projects/commembed/notebooks_final/../commembed/plots/social_dimensions.py:271: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   to_scatter = to_scatter[np.abs(x - mean) >= render_thresh]
# /ada/projects/commembed/notebooks_final/../commembed/plots/social_dimensions.py:271: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   to_scatter = to_scatter[np.abs(x - mean) >= render_thresh]
# /ada/projects/commembed/notebooks_final/../commembed/plots/social_dimensions.py:271: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   to_scatter = to_scatter[np.abs(x - mean) >= render_thresh]

# %%
# Save figures
save_paper_figure(many_densities_plot(['age', 'gender', 'partisan'], percentilize=True, single_column=True), "fig_2_densities")
save_paper_figure(many_densities_plot(['age', 'gender', 'partisan'], clustering_name="reddit_all_numbered", percentilize=False), "fig_A_densities_0", filetype='tiff')


save_paper_figure(many_densities_plot(['affluence','time', 'sociality', 'edginess'], clustering_name="reddit_all_numbered", percentilize=False), "fig_A_densities_2", filetype='tiff')
# Out:
# /ada/projects/commembed/notebooks_final/../commembed/plots/social_dimensions.py:271: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   to_scatter = to_scatter[np.abs(x - mean) >= render_thresh]
# /ada/projects/commembed/notebooks_final/../commembed/plots/social_dimensions.py:271: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   to_scatter = to_scatter[np.abs(x - mean) >= render_thresh]
# /ada/projects/commembed/notebooks_final/../commembed/plots/social_dimensions.py:271: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   to_scatter = to_scatter[np.abs(x - mean) >= render_thresh]
# Aspect ratio: 1.4547
# Saved fig_2_densities
# /ada/projects/commembed/notebooks_final/../commembed/plots/social_dimensions.py:271: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   to_scatter = to_scatter[np.abs(x - mean) >= render_thresh]
# ...

# %%
# save raw data
many_densities_plot(['age', 'gender', 'partisan', 'age_neutral', 'gender_neutral', 'partisan_neutral', 'affluence',
                    'time', 'sociality', 'edginess'], percentilize=True, clustering_name="reddit_all_numbered", export_raw_data=True)
plt.close()
# Out:
# /ada/projects/commembed/notebooks_final/../commembed/plots/social_dimensions.py:271: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   to_scatter = to_scatter[np.abs(x - mean) >= render_thresh]
# /ada/projects/commembed/notebooks_final/../commembed/plots/social_dimensions.py:271: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   to_scatter = to_scatter[np.abs(x - mean) >= render_thresh]
# /ada/projects/commembed/notebooks_final/../commembed/plots/social_dimensions.py:271: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   to_scatter = to_scatter[np.abs(x - mean) >= render_thresh]
# /ada/projects/commembed/notebooks_final/../commembed/plots/social_dimensions.py:271: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   to_scatter = to_scatter[np.abs(x - mean) >= render_thresh]
# ...

# %%
# Print skews and variances for main text
print_skews_and_variances(pairs=[
            ("Programming", "gender"),
            ("Programming", "age"),
            ("Personal matters", "gender"),
            ("Personal matters", "partisan"),
            ("Hobbies 1", "age"),
            ("Hobbies 1", "gender"),
            ("Hobbies 2", "age"),
            ("Hobbies 2", "gender"),
            ("History", "partisan"),
            ("History", "age"),
            ("Cars and motorcycles", "gender")
        ], bimodal_clusters=[
        ("Politics", "partisan"),
    ])
# Out:
#                                     word       frac  pctl    mean_z  \
# cluster              axis
# Programming          gender    masculine  36.099585    20 -0.581157
#                      age             old  50.207469    80  0.803055
# Personal matters     gender     feminine  76.650943    80  1.723628
#                      partisan  left wing  36.084906    20 -0.451622
# Hobbies 1            age             old  52.312139    80  0.831366
#                      gender    masculine  52.890173    20 -0.597618
# Hobbies 2            age             old  39.303483    80  0.572339
#                      gender     feminine  73.134328    80  1.261509
# History              partisan  left wing  49.664430    20 -0.797903
#                      age             old  42.953020    80  0.783167
# Cars and motorcycles gender    masculine  45.077720    20 -0.722089
#
#                                                                                                               desc
# ...
